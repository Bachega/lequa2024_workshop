# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Merge Meta-table Features and Meta-table Index

# %%
# meta_table_index_path = './merged/metafeatures/meta-features-table-index.csv'
# new_meta_table_index_path = './metafeatures/new_metafeatures_table/meta-features-table-index.csv'

# meta_table_index = pd.read_csv(meta_table_index_path)
# new_meta_table_index = pd.read_csv(new_meta_table_index_path)

# for row in new_meta_table_index.iterrows():
#     meta_table_index.loc[len(meta_table_index.index)] = row[1].values.tolist()

# meta_table_index.to_csv('./new_merged/metafeatures/meta-features-table-index.csv', index=False)




# meta_table_path = './merged/metafeatures/meta-features-table.csv'
# new_meta_table_path = './metafeatures/new_metafeatures_table/meta-features-table.csv'

# meta_table = pd.read_csv(meta_table_path)
# new_meta_table = pd.read_csv(new_meta_table_path)

# for row in new_meta_table.iterrows():
#     meta_table.loc[len(meta_table.index)] = row[1].values.tolist()

# meta_table.to_csv('./new_merged/metafeatures/meta-features-table.csv', index=False)

# %% [markdown]
# # Merge Experiment Tables

# %%
experiment_tables_path = './merged/experiment_tables/'
new_experiment_tables_path = './experiment_tables/new_new_experiment_tables/'

# processed_datasets = pd.read_csv(experiment_tables_path + 'processed_datasets.csv')
# new_processed_datasets = pd.read_csv(new_experiment_tables_path + 'processed_datasets.csv')

# for row in new_processed_datasets['dataset']:
#     processed_datasets.loc[len(processed_datasets.index)] = [row]

# processed_datasets.to_csv('./new_merged/experiment_tables/processed_datasets.csv', index=False)




# files = [f for f in os.listdir(experiment_tables_path) if f.endswith(".csv")]
# files.remove('processed_datasets.csv')
# # files.remove('experiment_table_MS2.csv')


# for dataset in files:
#     experiment_table = pd.read_csv(experiment_tables_path + dataset)
#     new_experiment_table = pd.read_csv(new_experiment_tables_path + dataset)

#     for row in new_experiment_table.iterrows():
#         experiment_table.loc[len(experiment_table.index)] = row[1].values.tolist()
    
#     experiment_table.to_csv('./new_merged/experiment_tables/' + dataset, index=False)
